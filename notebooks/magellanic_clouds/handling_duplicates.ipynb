# %%
import pandas as pd
import numpy as np
import numpy as np
import matplotlib.pyplot as plt

# %%
full = pd.read_csv('/home/shared/splus_gaia/data/h-alpha-selection-marina/MC/all_detections_mc.csv')
# Out:
# /tmp/ipykernel_253878/749054019.py:1: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   full = pd.read_csv('/home/shared/splus_gaia/data/h-alpha-selection-marina/MC/all_detections_mc.csv')

# %%
full.columns
# Out:
# Index(['id', 'ra', 'dec', 'mag_psf_g', 'mag_psf_i', 'mag_psf_j0378',
#        'mag_psf_j0395', 'mag_psf_j0410', 'mag_psf_j0430', 'mag_psf_j0515',
#        'mag_psf_j0660', 'mag_psf_j0861', 'mag_psf_r', 'mag_psf_u', 'mag_psf_z',
#        'err_mag_psf_g', 'err_mag_psf_i', 'err_mag_psf_j0378',
#        'err_mag_psf_j0395', 'err_mag_psf_j0410', 'err_mag_psf_j0430',
#        'err_mag_psf_j0515', 'err_mag_psf_j0660', 'err_mag_psf_j0861',
#        'err_mag_psf_r', 'err_mag_psf_u', 'err_mag_psf_z',
#        'h_alpha_emitters_8sigma', 's2noise_r', 'unique_values_kept',
#        'outside_cluster', 'cluster_index', 'star_index', 'sep_arcsec',
#        'sep_arcmin', 'cluster_ra', 'cluster_dec', 'cluster_amaj',
#        'cluster_Names', 'cluster_Type', 'cluster_[M/H]', 'cluster_r_[M/H]',
#        'star_ra', 'star_dec', 'star_id', 'Figueiredo_Be', 'Names', 'logAge',
#        'be_candidates_by_color', 'name', 'Age', 'Age2', 'AgeBicaGlatt',
# ...

# %%
#order full df by the column sep_arcsec and then drop duplicates based on the id column, keeping the first occurrence
full_n = full.sort_values('sep_arcsec', ascending=True).drop_duplicates(subset='id', keep='first')

# %%
full_n
# Out:
#                      id         ra        dec  mag_psf_g  mag_psf_i  \
# 1735776  i06MC01290982F  80.995796 -72.910573  17.577831  17.740843
# 2655261  i06MC011409PCI  10.594916 -73.088600  18.753288  17.980427
# 114889   i06MC006507M5L  84.570912 -69.725009  14.891847  13.312550
# 4383651  i06MC009504ML3  16.774258 -72.362491  18.256983  18.821080
# 4605716  i06MC011602XIV  16.420096 -73.597797  18.480887  18.950555
# ...                 ...        ...        ...        ...        ...
# 9851610  i06MC00630HH8J  74.538507 -68.995977  20.020370  18.978193
# 9851611  i06MC00150B3Y8  81.296374 -63.831396  19.649454  18.355351
# 9851612  i06MC00870FEBJ  77.178672 -70.310665        NaN  18.819698
# 9851613  i06MC00620000P  69.492552 -70.411438  20.848533  17.626540
# 9851614  i06MC006305LFO  77.092854 -69.956495  18.251481  20.682497
#
#          mag_psf_j0378  mag_psf_j0395  mag_psf_j0410  mag_psf_j0430  \
# 1735776      18.185911      17.801041      17.581421      17.487210
# ...

# %%
full_n.to_csv('/home/shared/splus_gaia/data/h-alpha-selection-marina/MC/all_detections_mc_unique.csv', index=False)
